# %% [markdown]
# <a href="https://colab.research.google.com/github/snitraM4500/number_guess/blob/main/tryout.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df=pd.read_excel("Relatorio_05-2024.xlsx")

df.head(3)

df.tail(3)
# Out:
#               Tipo Cidade    Produto  Qtde de Unidades Vendidas  \
# 697  Vendas online  Pemba  Produto 3                      914.0
# 698  Vendas online  Pemba  Produto 4                      914.0
# 699  Vendas online  Pemba  Produto 5                     1806.0
#
#      Preço Unitário  Valor Total  Desconto  Valor Total c/ Desconto  \
# 697              12      10968.0    1645.2                   9322.8
# 698              12      10968.0    1645.2                   9322.8
# 699              12      21672.0    3250.8                  18421.2
#
#      Custo Total    Lucro       Data       Mês   Ano
# 697       2742.0   6580.8 2019-12-01  Dezembro  2019
# 698       2742.0   6580.8 2019-12-01  Dezembro  2019
# 699       5418.0  13003.2 2019-05-01      Maio  2019

# %%
df.shape
# Out:
# (700, 13)

# %%
df.Produto.value_counts()
# Out:
# Produto
# Produto 3    202
# Produto 5    109
# Produto 4    109
# Produto 6     94
# Produto 1     93
# Produto 2     93
# Name: count, dtype: int64

# %%
df.Tipo.value_counts()
# Out:
# Tipo
# Governo              300
# Grandes empresas     100
# Médias empresas      100
# Pequenas empresas    100
# Vendas online        100
# Name: count, dtype: int64

# %%
df.describe().round(2)
# Out:
#        Qtde de Unidades Vendidas  Preço Unitário  Valor Total   Desconto  \
# count                     700.00          700.00       700.00     700.00
# mean                     1608.29          118.43    182759.43   13150.35
# min                       200.00            7.00      1799.00       0.00
# 25%                       905.00           12.00     17391.75     800.32
# 50%                      1542.50           20.00     37980.00    2585.25
# 75%                      2229.12          300.00    279025.00   15956.34
# max                      4492.50          350.00   1207500.00  149677.50
# std                       867.43          136.78    254262.28   22962.93
#
#        Valor Total c/ Desconto  Custo Total      Lucro                 Data  \
# count                   700.00       700.00     700.00                  700
# mean                 169609.07    147187.85   22421.22  2019-04-28 21:36:00
# min                    1655.08       918.00  -71250.25  2018-09-01 00:00:00
# ...
